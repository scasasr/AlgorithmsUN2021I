# %% [markdown]
# <a href="https://colab.research.google.com/github/scasasr/AlgorithmsUN2021I/blob/main/Lab3/scasasrLinkedin.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# [Perfil linkedin- link](https://www.linkedin.com/in/sebastian-camilo-casas-rojas-95157020b/)
#
# ![image.png](data:image/png;base64,...)
